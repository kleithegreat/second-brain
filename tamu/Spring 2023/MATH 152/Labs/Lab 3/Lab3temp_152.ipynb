# %% [markdown]
# ## MATH 152 Lab  3

# %% [markdown]
# Put team members' names and section number here.

# %%
from sympy import *
from sympy.plotting import (plot,plot_implicit)

# %% [markdown]
# ### Question 1

# %% [markdown]
# #### 1a

# %%
#start code here
x = symbols("x")
blue = x * E**(1 - x/2)
grey = x
green = (x**2) / 2

v = integrate(pi * 2**2, (x, 0, 2)) - integrate(pi * blue**2, (x, 0, 2))
print(f"{v} or {N(v)}")
# Out:
# -2*pi*exp(2) + 18*pi or 10.1218590498895

# %% [markdown]
# #### 1b

# %%
#start code here
y = symbols("y")
expr = y - x * E**(1 - x/2)
invBlue = solve(expr, x)
v = pi * integrate(invBlue[0]**2, (y, 0, 2))
print(f"{v} or {N(v)}")
# Out:
# pi*(88 - 32*E) or 3.18865839034766

# %% [markdown]
# #### 1c

# %%
v = integrate(pi * blue**2, (x, 0, 2)) - integrate(pi * grey**2, (x, 0, 2))
print(f"{v} or {N(v)}")
# Out:
# -38*pi/3 + 2*pi*exp(2) or 6.63330176925606

# %% [markdown]
# #### 1d

# %%
expr = y - (x**2 / 2)
invGreen = sqrt(2*y)#solve(expr, x)[1]
v = pi * integrate((2.5 - y)**2 - (2.5 - invGreen)**2, (y, 0, 2))
print(f"{v} or {N(v)}")
# Out:
# 2.0*pi or 6.28318530717958

# %% [markdown]
# ### Question 2

# %% [markdown]
# #### 2a

# %%
#start code here
rho = 1000
g = 9.8
low = 0
high = 2
Ai = (15/2)*y
di = 3 - y
work = rho * g * integrate(Ai * di, (y, low, high))
print(f"{work} newton meters of work")
# Out:
# 245000.000000000 newton meters of work

# %% [markdown]
# #### 2b

# %%
#start code here
high = y
height = solve(rho * g * integrate(Ai * di, (y, low, high)) - 3 * 10**4, real=True)
print(f"The remaining water is {re(height[1])} meters deep.")
# Out:
# The remaining water is 0.557288505751348 meters deep.

# %% [markdown]
# ### Question 3

# %% [markdown]
# #### 3a

# %%
#start code here
fx = cos(x)**2
gx = cos(x)**4

plot(fx, gx, (x, 0, pi/2))
print(N(pi * integrate(solve(cos(x)**2 - y, x)[3]**2 - solve(cos(x)**4 - y, x)[7]**2, (y, 0, 1))))
# Out:
# 0.968946146259369

# %% [markdown]
# #### 3b

# %%
area = integrate(fx, (x, 0, pi/2)) - integrate(gx, (x, 0, pi/2))
print(f"The area of the region is {area}")
# Out:
# The area of the region is pi/16

# %% [markdown]
# #### 3c

# %%
xbar = integrate(x*(fx - gx), (x, 0, pi/2)) / (integrate(fx, (x, 0, pi/2)) - integrate(gx, (x, 0, pi/2)))
print(N(xbar))
print("The center of mass value makes sense because it looks like the middle???")
# Out:
# 0.785398163397448
# The center of mass value makes sense because it looks like the middle???

# %% [markdown]
# #### 3d

# %%
distance = pi * (pi/2 - xbar)**2
print(f"The center of mass travels {distance} units far")
print(N(distance * area))
# Out:
# The center of mass travels pi**3/16 units far
# 0.380504261851572
