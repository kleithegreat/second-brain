# %% [markdown]
# ## MATH 152 Lab  7

# %% [markdown]
# Kevin Lei Grant Smith Alex Smolen Kevin Lee
# Section 542

# %%
from sympy import *
from sympy.plotting import (plot,plot_parametric)
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Question 1

# %% [markdown]
# #### 1a

# %%
n, ub = symbols("n ub")
expr = 1/n**4
sn = Sum(expr, (n, 1, ub))

s10 = sn.subs(ub, 10)
print(f"The partial sum of the series s10 is {N(s10)}")
print(f"The error in using s10 as an approximation of the sum of the series is {N(pi**4/90 - s10)}")
# Out:
# The partial sum of the series s10 is 1.08203658349376
# The error in using s10 as an approximation of the sum of the series is 0.000286650217381645

# %% [markdown]
# #### 1b

# %%
lower_estimate = sn.subs(ub, 10) + integrate(expr, (n, 11, oo))
upper_estimate = sn.subs(ub, 10) + integrate(expr, (n, 10, oo))
print(f"The sum of the series is between {N(lower_estimate)} and {N(upper_estimate)}")
# Out:
# The sum of the series is between 1.08228702176072 and 1.08236991682709

# %% [markdown]
# #### 1c

# %%
print(f"The error in the lower estimate is {N(pi**4/90 - lower_estimate)}")
print(f"The error in the upper estimate is {N(upper_estimate - pi**4/90)}")
# Out:
# The error in the lower estimate is 0.0000362119504144521
# The error in the upper estimate is 0.0000466831159516886

# %% [markdown]
# #### 1d

# %%
i = 10
while N(pi**4/90 - sn.subs(ub, i)) > 10**(-6):
    i += 1
print(f"The number of terms needed to get an error of 10^-6 is {i}")
# Out:
# The number of terms needed to get an error of 10^-6 is 69

# %% [markdown]
# ### Question 2

# %% [markdown]
# #### 2a

# %%
x = symbols("x")
expr = n**2 * E**(-n)
series = Sum(expr, (n, 2, oo))
fx = x**2 * E**(-x)

print(f"The indefintie integral of f(x) is {integrate(fx, x)}")
print(F"The definite integral of f(x) from 1 to infinity is {N(integrate(fx, (x, 1, oo)))}")
# Out:
# The indefintie integral of f(x) is (-x**2 - 2*x - 2)*exp(-x)
# The definite integral of f(x) from 1 to infinity is 1.83939720585721

# %% [markdown]
# #### 2b

# %%
print("Based on the answer in part a, the series converges for all n >= 2 by the integral test.")
# Out:
# Based on the answer in part a, the series converges for all n >= 2 by the integral test.

# %% [markdown]
# #### 2c

# %%
sn = Sum(expr, (n, 2, ub))
s10 = sn.subs(ub, 10)
s50 = sn.subs(ub, 50)
s100 = sn.subs(ub, 100)
s = sn.subs(ub, oo)
print(f"The 10th partial sum of the series is {N(s10)}")
print(f"The 50th partial sum of the series is {N(s50)}")
print(f"The 100th partial sum of the series is {N(s100)}")
print(f"The sum of the series is {N(s)}")
# Out:
# The 10th partial sum of the series is 1.62084673541930
# The 50th partial sum of the series is 1.62441532595354
# The 100th partial sum of the series is 1.62441532595354
# The sum of the series is 1.62441532595354

# %% [markdown]
# #### 2d

# %%
r100 = integrate(expr, (n, 100, oo))
error = N(s - s100)
print(f"The remainder estimate for the integral test for the 100th partial sum is {N(r100)}")
print(f"The actual value of the error is {error}")
print(f"The larger error is the remainder estimate.")
# Out:
# The remainder estimate for the integral test for the 100th partial sum is 3.79522151073646E-40
# The actual value of the error is 2.23423822900972E-40
# The larger error is the remainder estimate.

# %% [markdown]
# #### 2e

# %%
i = 2
while integrate(expr, (n, i, oo)) > 10**(-10):
    i += 1

print(f"The number of terms needed to get an error of 10^-10 is {i}")
print(f"The value of s - s{i} is {N(s - sn.subs(ub, i))} which is less than 10^-10")
# Out:
# The number of terms needed to get an error of 10^-10 is 30
# The value of s - s30 is 5.43688886516869E-11 which is less than 10^-10

# %% [markdown]
# ### Question 3

# %% [markdown]
# #### 3a

# %%
an = (n * sin(n)**2) / (1 + n**3)
s = Sum(an, (n, 1, oo))

bn = 1 / n**2
print(f"The sequence an can be compared to the sequence bn which is {bn}")
# Out:
# The sequence an can be compared to the sequence bn which is n**(-2)

# %% [markdown]
# #### 3b

# %%
anvals = [an.subs(n, i) for i in range(1, 51)]
bnvals = [bn.subs(n, i) for i in range(1, 51)]
plt.figure()
plt.plot(range(1, 51), anvals,"o",label="an")
plt.plot(range(1, 51), bnvals,"o",label="bn")
plt.legend()
plt.show()

print(f"The sequence bn is larger than an.")
# Out:
# The sequence bn is larger than an.

# %% [markdown]
# #### 3c

# %%
print(f"The sum of bn is convergent by the integral test.")
print(f"It can be concluded that an is convergent by comparison to bn.")
# Out:
# The sum of bn is convergent by the integral test.
# It can be concluded that an is convergent by comparison to bn.

# %% [markdown]
# #### 3d

# %%
print(f"The conclusion in part c is conclusive")
# Out:
# The conclusion in part c is conclusive

# %% [markdown]
# ### Question 3 (part 2)

# %% [markdown]
# #### 3a.2

# %%
an = (E**n + 1) / (n * E**n + 1)
bn = 1 / n
print(f"The new sequence an can be compared to the sequence bn which is {bn}")
# Out:
# The new sequence an can be compared to the sequence bn which is 1/n

# %% [markdown]
# #### 3b.2

# %%
anvals = [an.subs(n, i) for i in range(1, 51)]
bnvals = [bn.subs(n, i) for i in range(1, 51)]
plt.figure()
plt.plot(range(1, 51), anvals,"o",label="an")
plt.plot(range(1, 51), bnvals,"o",label="bn")
plt.legend()
plt.show()

print(f"The sequence bn is smaller than an.")
# Out:
# The sequence bn is smaller than an.

# %% [markdown]
# #### 3c.2

# %%
print(f"The sum of bn is divergent by the integral test.")
print(f"It can be concluded that an is divergent by comparison to bn.")
# Out:
# The sum of bn is divergent by the integral test.
# It can be concluded that an is divergent by comparison to bn.
