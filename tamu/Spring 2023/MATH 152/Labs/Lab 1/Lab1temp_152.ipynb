# %% [markdown]
# ## MATH 152 Lab  1

# %% [markdown]
# Put team members' names and section number here.

# %%
from sympy import *
from sympy.plotting import (plot,plot_parametric)

# %% [markdown]
# ### Question 1

# %% [markdown]
# #### 1a

# %%
#start code here

# %% [markdown]
# #### 1b

# %%
#start code here

# %% [markdown]
# ### Question 2

# %% [markdown]
# #### 2a

# %%
#start code here

# %% [markdown]
# #### 2b

# %%
#start code here

# %% [markdown]
# ### Question 3

# %% [markdown]
# #### 3a

# %%
#start code here

# %% [markdown]
# #### 3b

# %%
#start code here

# %% [markdown]
# ##Question 4

# %% [markdown]
# ###4a

# %%
#start code here

# %% [markdown]
# ###4b

# %%
#start code here

# %% [markdown]
# ###4c

# %%
#start code here

# %% [markdown]
# ###4d

# %%
#start code here
