# %% [markdown]
# ## MATH 152 Lab  2

# %% [markdown]
# Put team members' names and section number here.

# %%
from sympy import *
from sympy.plotting import (plot,plot_implicit)

# %% [markdown]
# ### Question 1

# %% [markdown]
# #### 1a

# %%
#start code here
x, y = symbols("x y")

equation = Eq(x, -1 * y**2 + 5*y - 3)
plot_implicit(equation, (x, -10, 10), (y, -2, 5))

# %% [markdown]
# #### 1b

# %%
#start code here
print(solve(equation.subs(x, 0), y))
# Out:
# [5/2 - sqrt(13)/2, sqrt(13)/2 + 5/2]

# %% [markdown]
# #### 1c

# %%
volume = integrate(pi * (-1 * y**2 + 5*y - 3)**2, (y, solve(equation.subs(x, 0), y)[0], solve(equation.subs(x, 0), y)[1]))
print(N(volume))
# Out:
# 63.8097434818162

# %% [markdown]
# ### Question 2

# %% [markdown]
# #### 2a

# %%
#start code here
volume = integrate(pi * cos(x)**2, (x, 0, solve(sin(x) - cos(x))[0])) - integrate(pi * sin(x)**2, (x, 0, solve(sin(x) - cos(x))[0]))
print(N(volume))
# Out:
# -pi*(-1/4 + pi/8) + pi*(1/4 + pi/8)
# 1.57079632679490

# %% [markdown]
# #### 2b

# %%
#start code here
volume = pi * integrate(asin(y)**2, (y, 0, sqrt(2)/2)) + pi * integrate(acos(y)**2, (y, sqrt(2)/2, 1))
print(N(volume))
# Out:
# 0.695678892459293

# %% [markdown]
# #### 2c

# %%
volume = 2 * pi * integrate(x * (cos(x) - sin(x)), (x, 0, pi/4))
print(N(volume))
# Out:
# 0.695678892459293

# %% [markdown]
# ### Question 3

# %% [markdown]
# #### 3a

# %%
#start code here
fx = 12 / (8 + x**4)

plot((fx, (x, -3 ,3)), (-1 * fx, (x, -3 ,3)))

# %% [markdown]
# #### 3b

# %%
#start code here
surfaceArea = integrate(fx, (x, -3, 3)) - integrate(-fx, (x, -3, 3))
print(N(surfaceArea))
# Out:
# 10.6390331471780

# %% [markdown]
# #### 3c

# %%
volume = integrate(pi * fx**2, (x, -3, 3))
print(N(volume))
# Out:
# 19.7537908960011

# %% [markdown]
# ##Question 4

# %% [markdown]
# ###4ai

# %%
#start code here
f=(E**(-sqrt(x)))
g=((E**(-cos(x)))*(sin(2*x)))
h=((2*x)*(E**(-x)))

fint=integrate(f,(x,0,1))
gint=integrate(g,(x,0,pi/2))
hint=integrate(h,(x,0,1))

print("Integration of f is ", fint.evalf())
# Out:
# Integration of f is  0.528482235314231

# %% [markdown]
# ###4aii

# %%
#start code here
print("Integration of g is ", gint.evalf())
# Out:
# Integration of g is  0.528482235314231

# %% [markdown]
# ###4aiii

# %%
#start code here
print("Integration of h is ", hint.evalf())

print("Therefore, all three integrals are equal")
# Out:
# Integration of h is  0.528482235314231
# Therefore, all three integrals are equal

# %% [markdown]
# ###4b

# %%
#start code here
print("For the first integral (i), u has to be square root of x, which will make du as 1/2*u. Bound will not change as 0 and 1 stays the same under square root of x")
print("\n")
print("For the second integral (ii), u has to be cos(x), which will make du as -sin(x). Then change sin(2x) into 2sin(x)cos(x). sin(x) should be canceled out and bound will be changed [0,1]")
# Out:
# For the first integral (i), u has to be square root of x, which will make du as 1/2*u. Bound will not change as 0 and 1 stays the same under square root of x
#
#
# For the second integral (ii), u has to be cos(x), which will make du as -sin(x). Then change sin(2x) into 2sin(x)cos(x). sin(x) should be canceled out and bound will be changed [0,1]
