# %% [markdown]
# ## MATH 152 Lab  3

# %% [markdown]
# Put team members' names and section number here.

# %%
from sympy import *
from sympy.plotting import (plot,plot_implicit)

# %% [markdown]
# ### Question 1

# %% [markdown]
# #### 1a

# %%
#start code here
x = symbols("x")
blue = x * E**(1 - x/2)
grey = x
green = (x**2) / 2

v = integrate(pi * 2**2, (x, 0, 2)) - integrate(pi * blue**2, (x, 0, 2))
print(f"{v} or {N(v)}")
# Out:
# -2*pi*exp(2) + 18*pi or 10.1218590498895

# %% [markdown]
# #### 1b

# %%
#start code here
y = symbols("y")
expr = y - x * E**(1 - x/2)
invBlue = solve(expr, x)
v = pi * integrate(invBlue[0]**2, (y, 0, 2))
print(f"{v} or {N(v)}")
# Out:
# pi*(88 - 32*E) or 3.18865839034766

# %% [markdown]
# #### 1c

# %%
v = integrate(pi * blue**2, (x, 0, 2)) - integrate(pi * grey**2, (x, 0, 2))
print(f"{v} or {N(v)}")
# Out:
# -38*pi/3 + 2*pi*exp(2) or 6.63330176925606

# %% [markdown]
# #### 1d

# %%
v = 2 * pi * integrate( (2.5 - x) * (x - x**2/2) , (x, 0, 2) )
print(f"{v} or {N(v)}")
# Out:
# 2.0*pi or 6.28318530717959

# %% [markdown]
# ### Question 2

# %% [markdown]
# #### 2a

# %%
work = 9800 * integrate((15/2)*y * (3 - y), (y, 0, 2))
print(f"{work} newton meters of work")
# Out:
# 245000.000000000 newton meters of work

# %% [markdown]
# #### 2b

# %%
eq = Eq(9800 * integrate((15/2)*y * (3 - y), (y, x, 2)), 3*10**4)
height = solve(eq, x)

print(f"The remaining water is about {re(height[1])} meters deep.")
# Out:
# The remaining water is 1.80424791991912 meters deep.

# %% [markdown]
# ### Question 3

# %% [markdown]
# #### 3a

# %%
#start code here
fx = cos(x)**2
gx = cos(x)**4

plot(fx, gx, (x, 0, pi/2))
print(N(2*pi * integrate((pi/2 - x)*(fx - gx), (x, 0, pi/2)) ))
# Out:
# 0.968946146259369

# %% [markdown]
# #### 3b

# %%
area = integrate(fx, (x, 0, pi/2)) - integrate(gx, (x, 0, pi/2))
print(f"The area of the region is {area}")
# Out:
# The area of the region is pi/16

# %% [markdown]
# #### 3c

# %%
xbar = integrate(x*(fx - gx), (x, 0, pi/2)) / (integrate(fx, (x, 0, pi/2)) - integrate(gx, (x, 0, pi/2)))
print(N(xbar))
print("The center of mass value makes sense because it looks like a reasonable midpoint on the graph.")
# Out:
# 0.785398163397448
# The center of mass value makes sense because it looks like a reasonable midpoint on the graph.

# %% [markdown]
# #### 3d

# %%
distance = 2 * pi * (pi/2 - xbar)
print(f"The center of mass travels {distance} units far")
print(N(distance * area))
print("The distance traveled by the x coordinate of the center of mass multiplied by the area is the same as the volume found in part A.")
# Out:
# The center of mass travels pi**2/2 units far
# 0.968946146259369
# The distance traveled by the x coordinate of the center of mass multiplied by the area is the same as the volume found in part A.
